# %% [markdown]
# <a href="https://colab.research.google.com/github/jaisx2/Data-Analytics-Intern/blob/main/shopping%20mall_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Shopping Mall Customer Segmentation Data .csv')

# %%
df.head()
# Out:
#                             Customer ID  Age  Gender  Annual Income  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
# 3  9795712a-ad19-47bf-8886-4f997d6046e3   23    Male          55460
# 4  64139426-2226-4cd6-bf09-91bce4b4db5e   24    Male         153752
#
#    Spending Score
# 0              89
# 1              95
# 2              76
# 3              57
# 4              76

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15079 entries, 0 to 15078
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     15079 non-null  object
#  1   Age             15079 non-null  int64
#  2   Gender          15079 non-null  object
#  3   Annual Income   15079 non-null  int64
#  4   Spending Score  15079 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 589.2+ KB

# %%
df.describe()
# Out:
#                 Age  Annual Income  Spending Score
# count  15079.000000   15079.000000    15079.000000
# mean      54.191591  109742.880562       50.591617
# std       21.119207   52249.425866       28.726977
# min       18.000000   20022.000000        1.000000
# 25%       36.000000   64141.000000       26.000000
# 50%       54.000000  109190.000000       51.000000
# 75%       72.000000  155008.000000       75.000000
# max       90.000000  199974.000000      100.000000

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# customer_id       0
# age               0
# gender            0
# annual_income     0
# spending_score    0
# dtype: int64

# %%
df['age'].fillna(df['age'].mean(), inplace=True)
# Out:
# <ipython-input-11-15e9ed7dc05b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(), inplace=True)

# %%
df['gender'].fillna(df['gender'].mode()[0], inplace=True)
# Out:
# <ipython-input-12-b1680f0d9722>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].fillna(df['gender'].mode()[0], inplace=True)

# %%
df['age'] = df['age'].astype(int)

# %%
df.head()
# Out:
#                             customer_id  age  gender  annual_income  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
# 3  9795712a-ad19-47bf-8886-4f997d6046e3   23    Male          55460
# 4  64139426-2226-4cd6-bf09-91bce4b4db5e   24    Male         153752
#
#    spending_score
# 0              89
# 1              95
# 2              76
# 3              57
# 4              76

# %%
df = pd.get_dummies(df, columns=['gender'], drop_first=True)

# %%
df.head()
# Out:
#                             customer_id  age  annual_income  spending_score  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30         151479              89
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58         185088              95
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62          70912              76
# 3  9795712a-ad19-47bf-8886-4f997d6046e3   23          55460              57
# 4  64139426-2226-4cd6-bf09-91bce4b4db5e   24         153752              76
#
#    gender_Male
# 0         True
# 1        False
# 2        False
# 3         True
# 4         True

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['annual_income', 'spending_score']] = scaler.fit_transform(df[['annual_income', 'spending_score']])

# %%
df.head()
# Out:
#                             customer_id  age  annual_income  spending_score  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30       0.798813        1.337059
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58       1.442076        1.545929
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62      -0.743208        0.884507
# 3  9795712a-ad19-47bf-8886-4f997d6046e3   23      -1.038953        0.223086
# 4  64139426-2226-4cd6-bf09-91bce4b4db5e   24       0.842317        0.884507
#
#    gender_Male
# 0         True
# 1        False
# 2        False
# 3         True
# 4         True

# %%
df['income_per_age'] = df['annual_income'] / df['age']

# %%
df.head()
# Out:
#                             customer_id  age  annual_income  spending_score  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30       0.798813        1.337059
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58       1.442076        1.545929
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62      -0.743208        0.884507
# 3  9795712a-ad19-47bf-8886-4f997d6046e3   23      -1.038953        0.223086
# 4  64139426-2226-4cd6-bf09-91bce4b4db5e   24       0.842317        0.884507
#
#    gender_Male  income_per_age
# 0         True        0.026627
# 1        False        0.024863
# 2        False       -0.011987
# 3         True       -0.045172
# 4         True        0.035097

# %%
df.to_csv("cleaned_customer_data.csv", index=False)

# %%
df.head()
# Out:
#                             customer_id  age  annual_income  spending_score  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30       0.798813        1.337059
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58       1.442076        1.545929
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62      -0.743208        0.884507
# 3  9795712a-ad19-47bf-8886-4f997d6046e3   23      -1.038953        0.223086
# 4  64139426-2226-4cd6-bf09-91bce4b4db5e   24       0.842317        0.884507
#
#    gender_Male  income_per_age
# 0         True        0.026627
# 1        False        0.024863
# 2        False       -0.011987
# 3         True       -0.045172
# 4         True        0.035097

# %%
df.to_csv('cleaned_data.csv', index=False)
from google.colab import files
files.download('cleaned_data.csv')
